# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1nq_J8NBY1oLTIDvaUo2s6cdgZtrwzn-B?usp=sharing)
#
# # Pandas preliminaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import dataset

# %%
data_path = 'https://raw.githubusercontent.com/PhuThanh-Nguyen/Py4DS/main/Lab%2003/dataset/AB_NYC_2019.csv'

data = pd.read_csv(data_path)

# %%
data.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# # Data information

# %%
data.shape
# Out:
# (48895, 16)

# %%
# The field name of data
print("The field name of data: ", data.columns)

# Number of fields in data
print("Number of fields in data: ", len(data.columns))

# Number of data in data
print("Number of data in data: ", len(data))
# Out:
# The field name of data:  Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')
# Number of fields in data:  16
# Number of data in data:  48895

# %%
# View information such as data field properties and count
# For find out how much of datas were null
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# statistical discription of data
data.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.885800e+04  4.885800e+04  48858.000000  48858.000000  48858.000000
# mean   1.902335e+07  6.763169e+07     40.728941    -73.952170    152.740309
# std    1.098289e+07  7.862389e+07      0.054528      0.046159    240.232386
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.475980e+06  7.818669e+06     40.690090    -73.983070     69.000000
# 50%    1.969114e+07  3.079133e+07     40.723070    -73.955680    106.000000
# 75%    2.915765e+07  1.074344e+08     40.763107    -73.936280    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48858.000000       48858.000000       48858.000000
# mean         7.012444          23.273098           1.091124
# std         20.019757          44.549898           1.597270
# ...

# %% [markdown]
# # Dealing with missing values

# %% [markdown]
# # Count missing values

# %%
# Check the number of nulls in each field
data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ## Calculate percentage of misssing values in each field

# %%
pd.DataFrame({'column_name': data.columns,
              'total_missing': data.isnull().sum(),
                '%_missing': data.isnull().sum() * 100 / len(data)}).reset_index(drop=True)
# Out:
#                        column_name  total_missing  %_missing
# 0                               id              0   0.000000
# 1                             name             16   0.032723
# 2                          host_id              0   0.000000
# 3                        host_name             21   0.042949
# 4              neighbourhood_group              0   0.000000
# 5                    neighbourhood              0   0.000000
# 6                         latitude              0   0.000000
# 7                        longitude              0   0.000000
# 8                        room_type              0   0.000000
# 9                            price              0   0.000000
# 10                  minimum_nights              0   0.000000
# 11               number_of_reviews              0   0.000000
# 12                     last_review          10052  20.558339
# 13               reviews_per_month          10052  20.558339
# ...

# %% [markdown]
# ## Replace by zeros (if possible, i.e: we can inference from other fields, etc)

# %% [markdown]
# check some datas which were null in `last_review` and `reviews_per_month`, and in some of them, the `number_of_reviews` was 0. So it's obvious that when `number_of_reviews` was 0 these two columns will be zero. therefore we will put zero on null column.

# %%
data.loc[data.number_of_reviews==0, 'reviews_per_month'] = 0
data.loc[data.number_of_reviews==0, 'last_review'] = 0

# %%
data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ## Drop out misssing (Null/NaN) *values*

# %%
# Removing null values in name and host_name fields
data = data[pd.notnull(data['name'])]
data = data[pd.notnull(data['host_name'])]

# %% [markdown]
# See: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html

# %%
data.shape
# Out:
# (48858, 16)

# %%
# Recheck the number of nulls in each field
data.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# # Exploratory data analysis (EDA)

# %%
data.sort_values(by=['price'])
# Out:
#              id                                               name    host_id  \
# 26866  21304320             Best Coliving space ever! Shared room.  101970559
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 25794  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 26259  20933849                              the best you can find   13709292
# 26841  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# ...         ...                                                ...        ...
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 6530    4737930                                 Spanish Harlem Apt    1235070
# 9151    7003697                Furnished room in Astoria apartment   20582832
# 29238  22436899                                1-BR Lincoln Center   72390391
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
#
# ...

# %%
# Notice at `std`
data.price.describe()
# Out:
# count    48858.000000
# mean       152.740309
# std        240.232386
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.hist(data.price, bins=50)
plt.show()

# %% [markdown]
# ## Exercise

# %%
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Which neighborhood has the most hosts?
data.groupby(by=['neighbourhood']).neighbourhood.count()
# Out:
# neighbourhood
# Financial District    85454
# Murray Hill           26125
# Hell's Kitchen        25169
# Midtown               25019
# Theater District      18704
#                       ...
# West Farms                2
# Rossville                 1
# Richmondtown              1
# Woodrow                   1
# New Dorp                  1
# Name: calculated_host_listings_count, Length: 221, dtype: int64

# %%
# Which neighborhood has the most expensive?
data.groupby('neighbourhood').price.mean().sort_values(ascending=False)
# Out:
# neighbourhood
# Bull's Head        47.333333
# Hunts Point        50.500000
# Tremont            51.545455
# Soundview          53.466667
# New Dorp           57.000000
#                      ...
# Riverdale         442.090909
# Sea Gate          487.857143
# Tribeca           490.638418
# Woodrow           700.000000
# Fort Wadsworth    800.000000
# Name: price, Length: 221, dtype: float64

# %%
# Which room_type Airbnb has and how many of each?
data.groupby('room_type')["room_type"].count()
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
# Which room_type have more reviews?
data.groupby('room_type').sum()['number_of_reviews']
# Out:
# room_type
# Entire home/apt    580403
# Private room       538346
# Shared room         19256
# Name: number_of_reviews, dtype: int64

# %%
# Which hosts has more cabin?
data.groupby(by=['host_name']).host_name.count().sort_values(ascending=False)
# Out:
# host_name
# Michael         417
# David           403
# Sonder (NYC)    327
# John            294
# Alex            279
#                ...
# Jerbean           1
# Jerald            1
# Jeonghoon         1
# Jeny              1
# 현선                1
# Name: room_type, Length: 11452, dtype: int64

# %%
# Which host has the cheapest cabins?
data.groupby(by=['host_name']).price.mean()

# %%
# Which neighbourhood_group is the biggest one?
data.groupby(by=['neighbourhood_group']).neighbourhood_group.count()

# %%
# Which neighbourhood has the most possibility to available in year?

# %%
# Which neigbourhood_group has the best hosts to stay for a few nights?

# %%
# Which neigbourhood has the best hosts to stay for a few nights?

# %% [markdown]
# # Linear Regression

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# %%
# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2] # diabetes_X[:, 2].reshape(-1,1)
diabetes_X.shape
# Out:
# (442, 1)

# %%
# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# %%
# Create linear regression object
regr = linear_model.Ridge(alpha=.01)

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# %%
# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# Coefficients:
#  [928.52207357]
# Mean squared error: 2559.32
# Coefficient of determination: 0.47

# %%
# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test, color="black")
plt.plot(diabetes_X_test, diabetes_y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
